# %% [markdown]
# # Variant disease phenotypes
#
# This analysis aimed to answer the following research question: **How many of the variants identified in African populations have known disease associations, and what are these associations?**
#
# To achieve this, the following steps were performed:
#
# 1. Genetic Variant Phenotype Data Retrieval and Preparation: Known disease phenotypes for the variants were retrieved from [Favor v2.0](https://favor.genohub.org/). The retrieved data underwent processing and preparation following guidelines outlined in the [Notebooks\Data_preparation\6-Variant_phenotype_associations.ipynb](https://github.com/MeganHolborn/Genetic_data_analysis/blob/main/Notebooks/Data_preparation/6-Variant_phenotype_associations.ipynb) Jupyter notebook. The processed data can be found [here](https://github.com/MeganHolborn/Genetic_data_analysis/blob/main/Data/Processed/Variant_disease_phenotypes.csv).
# 2. Analysis and Visualisation:
#     * To be completed...

# %% [markdown]
# ## Imports

# %% [markdown]
# Notebook setup

# %%
import os
import sys

from dotenv import load_dotenv

load_dotenv()

PROJECT_ROOT = os.getenv("PROJECT_ROOT")
if PROJECT_ROOT not in sys.path:
    os.chdir(PROJECT_ROOT + "/Notebooks")
    sys.path.append(PROJECT_ROOT)

import numpy as np
import pandas as pd
import seaborn as sns
import upsetplot
from matplotlib import pyplot as plt
import Utils.constants as constants
import Utils.functions as functions

# %% [markdown]
# Import variant phenotype data

# %%
phenotype_data = pd.read_csv(
    os.path.join(
        PROJECT_ROOT,
        "Data",
        "Processed",
        "Variant_disease_phenotypes.csv",
    )
)

phenotype_data.head(5)
# Out:
#            VariantVcf         Rsid Clndn  CHROM        POS  REF ALT  \
# 0    13-110148917-C-G   rs59409892   NaN     13  110148917    C   G
# 1    13-110148891-C-G  rs552586867   NaN     13  110148891    C   G
# 2    13-110149494-C-T  rs552877576   NaN     13  110149494    C   T
# 3  13-110149715-AAT-A  rs886049952   NaN     13  110149715  AAT   A
# 4    13-110151168-C-T  rs557686466   NaN     13  110151168    C   T
#
#                 ID
# 0    110148917_C_G
# 1    110148891_C_G
# 2    110149494_C_T
# 3  110149715_AAT_A
# 4    110151168_C_T

# %% [markdown]
# Import genetic variant count data for African populations

# %%
ih_afr = pd.read_csv(
    os.path.join(
        PROJECT_ROOT,
        "Data",
        "Processed",
        "IH_allele_counts.csv",
    )
)

ih_afr.head(5)
# Out:
#                ID             VAR_NAME        POS REF ALT    GENE  \
# 0  110148882_C_CT  chr13:110148882C-CT  110148882   C  CT  COL4A1
# 1  110148882_C_CT  chr13:110148882C-CT  110148882   C  CT  COL4A1
# 2  110148882_C_CT  chr13:110148882C-CT  110148882   C  CT  COL4A1
# 3  110148882_C_CT  chr13:110148882C-CT  110148882   C  CT  COL4A1
# 4  110148882_C_CT  chr13:110148882C-CT  110148882   C  CT  COL4A1
#
#        SUB_POP  IH_ALT_CTS  IH_TOTAL_CTS  IH_REF_CTS REG  IH_AF VARIANT_TYPE
# 0  Bantu Kenya           0            20          20  EA    0.0        INDEL
# 1       Yoruba           0           276         276  WA    0.0        INDEL
# 2          San           0            12          12  SA    0.0        INDEL
# 3        Mende           0           166         166  WA    0.0        INDEL
# 4  Mbuti Pygmy           0            24          24  CA    0.0        INDEL

# %% [markdown]
# Import genetic variant count data for global populations

# %%
alfa_global = pd.read_csv(
    os.path.join(
        PROJECT_ROOT,
        "Data",
        "Processed",
        "ALFA_allele_counts_b.csv",
    )
)

alfa_global.head(5)
# Out:
#   variant_id reference_allele alternate_allele  ALT_CT_ALFA_East Asian  \
# 0  rs1000343                C                T                     0.0
# 1  rs1000989                T                C                    55.0
# 2  rs1000990                T                C                    32.0
# 3  rs1005573                C                T                    35.0
# 4  rs1007311                A                G                    56.0
#
#    ALT_CT_ALFA_European  ALT_CT_ALFA_Latin American 1  \
# 0                  49.0                           5.0
# 1               21489.0                         123.0
# 2                5355.0                          40.0
# 3               10693.0                         209.0
# 4                9154.0                          61.0
#
#    ALT_CT_ALFA_Latin American 2  ALT_CT_ALFA_South Asian  \
# 0                          10.0                      0.0
# 1                        1330.0                   1685.0
# 2                         261.0                     36.0
# 3                        1810.0                     79.0
# 4                         154.0                     43.0
#
#    REF_CT_ALFA_East Asian  REF_CT_ALFA_European  REF_CT_ALFA_Latin American 1  \
# 0                   490.0              109377.0                         673.0
# 1                   109.0               37269.0                         273.0
# 2                    54.0                8931.0                         106.0
# 3                    69.0                4955.0                          87.0
# 4                    56.0               11242.0                          85.0
#
#    REF_CT_ALFA_Latin American 2  REF_CT_ALFA_South Asian
# 0                        2200.0                    184.0
# 1                        2052.0                   3283.0
# 2                         349.0                     62.0
# 3                         956.0                     31.0
# 4                         456.0                     55.0

# %% [markdown]
# Import variant effect data

# %%
vep_data = pd.read_csv(
    os.path.join(
        PROJECT_ROOT,
        "Data",
        "Processed",
        "Variant_effects.csv",
    )
)

vep_data.head(5)
# Out:
#    CHROM        POS REF ALT    GENE POLYPHEN_PRED  POLYPHEN_SCORE SIFT_PRED  \
# 0     13  110148882   C  CT  COL4A1           NaN             NaN       NaN
# 1     13  110148891   C   G  COL4A1           NaN             NaN       NaN
# 2     13  110148917   C   G  COL4A1           NaN             NaN       NaN
# 3     13  110148920   G   C  COL4A1           NaN             NaN       NaN
# 4     13  110148959   A   G  COL4A1           NaN             NaN       NaN
#
#    SIFT_SCORE  CADD_RAW_SCORE  CADD_PHRED_SCORE              ID
# 0         NaN       -0.437825             0.160  110148882_C_CT
# 1         NaN       -0.227221             0.446   110148891_C_G
# 2         NaN        0.269936             3.938   110148917_C_G
# 3         NaN        0.530972             6.825   110148920_G_C
# 4         NaN        1.380228            14.950   110148959_A_G

# %% [markdown]
# ## Analysis and Visualisation

# %% [markdown]
# ### Data selection

# %% [markdown]
# Select effect data on rare variants within African subpopulation (ethnolinguistic) groups for analysis.

# %%
# Select aggregated variant count and frequency data for Recent Africans. Remove variants with an alternate allele count of 0. These variants are not present in Recent Africans.

ih_afr_subpops = ih_afr[(ih_afr["REG"] == "Recent African") & (ih_afr["IH_ALT_CTS"] > 0)]

# Add in effect data for rare variants that are in the Recent African populations
ih_afr_subpops_phenotype_data = (
    ih_afr_subpops.merge(
        phenotype_data,
        how="left",
        left_on=["REF", "ALT", "POS"],
        right_on=["REF", "ALT", "POS"],
    )
    .drop(columns="ID_y")
    .rename(columns={"ID_x": "ID"})
)

ih_afr_subpops_phenotype_data.head(5)
# Out:
#               ID     VAR_NAME        POS REF ALT    GENE SUB_POP  IH_ALT_CTS  \
# 0  110148891_C_G  rs552586867  110148891   C   G  COL4A1     NaN           1
# 1  110148917_C_G   rs59409892  110148917   C   G  COL4A1     NaN         119
# 2  110149176_T_A  rs546124548  110149176   T   A  COL4A1     NaN           1
# 3  110149349_G_A  rs139916479  110149349   G   A  COL4A1     NaN           5
# 4  110149494_C_T  rs552877576  110149494   C   T  COL4A1     NaN           1
#
#    IH_TOTAL_CTS  IH_REF_CTS             REG     IH_AF VARIANT_TYPE  \
# 0          1220        1219  Recent African  0.000820          SNP
# 1          1220        1101  Recent African  0.097541          SNP
# 2          1220        1219  Recent African  0.000820          SNP
# 3          1220        1215  Recent African  0.004098          SNP
# 4          1220        1219  Recent African  0.000820          SNP
#
#          VariantVcf         Rsid  \
# 0  13-110148891-C-G  rs552586867
# 1  13-110148917-C-G   rs59409892
# 2  13-110149176-T-A  rs546124548
# 3  13-110149349-G-A  rs139916479
# 4  13-110149494-C-T  rs552877576
#
#                                                Clndn  CHROM
# 0                                                NaN   13.0
# 1                                                NaN   13.0
# 2                                                NaN   13.0
# 3  Brain_small_vessel_disease_1_with_or_without_o...   13.0
# 4                                                NaN   13.0

# %% [markdown]
# ### How many variants have previously been associated with HIE and are present in Africans?

# %% [markdown]
# Create a list of variants (with rsids) associated with HIE in the genes of interest. This information was retrieved from: https://doi.org/10.1016/j.ygeno.2022.110508.

# %%
hie_variant_rsids = [
    "rs2067853",
    "rs1217401",
    "rs2043211",
    "rs1001179",
    "rs1800896",
    "rs1071676",
    "rs1143623",
    "rs16944",
    "rs1800795",
    "rs1801133",
    "rs1808593",
    "rs2070744",
    "rs6517135",
    "rs1799964"
]

# %% [markdown]
# How many HIE-associated variants with rsids are there?

# %%
len(hie_variant_rsids)
# Out:
# 14

# %% [markdown]
# Which of these variants are present in Africans?

# %%
variants_with_hie_assoc = ih_afr_subpops_phenotype_data[ih_afr_subpops_phenotype_data.VAR_NAME.isin(hie_variant_rsids)]
variants_with_hie_assoc.VAR_NAME.unique()
# Out:
# array(['rs1071676', 'rs1217401', 'rs1801133', 'rs2070744', 'rs1808593',
#        'rs1800896', 'rs1800795', 'rs2067853', 'rs2043211'], dtype=object)

# %% [markdown]
# How many of the variants are present in Africans?

# %%
variants_with_hie_assoc.VAR_NAME.nunique()
# Out:
# 9

# %% [markdown]
# ### How many variants have a known ClinVar disease phenotype?

# %%
# Split the phenotypes listed in each row of the Clndn column into a list

ih_afr_subpops_phenotype_data['Clndn'] = ih_afr_subpops_phenotype_data['Clndn'].str.split('|')

# %%
# Convert the phenotypes list into multiple rows

ih_afr_subpops_phenotype_explode = ih_afr_subpops_phenotype_data.explode('Clndn')

# %%
# Remove rows with missing data for the Clndn column

variants_with_ClinVar_phenotypes = ih_afr_subpops_phenotype_explode[~((ih_afr_subpops_phenotype_explode['Clndn'].isna()) | (ih_afr_subpops_phenotype_explode['Clndn'] == 'not_provided') | (ih_afr_subpops_phenotype_explode['Clndn'] == 'not_specified') | (ih_afr_subpops_phenotype_explode['Clndn'] == 'not_specified|not_provided') | (ih_afr_subpops_phenotype_explode['Clndn'] == 'none_provided'))]

# %%
# Count the number of variants with disease phenotype descriptions

variants_with_ClinVar_phenotypes['ID'].nunique()
# Out:
# 133

# %%
variants_with_ClinVar_phenotypes[variants_with_ClinVar_phenotypes.VAR_NAME.isin(hie_variant_rsids)].ID.nunique()
# Out:
# 5

# %%
variants_with_known_phenotypes_grouped_by_gene = variants_with_ClinVar_phenotypes[['GENE','Clndn','ID']].groupby(['GENE','Clndn']).count().reset_index().sort_values(by=['GENE','ID'], ascending=True)
variants_with_known_phenotypes_grouped_by_gene.rename(columns={'ID':'Count'}, inplace=True)

variants_with_known_phenotypes_grouped_by_gene
# Out:
#       GENE                                              Clndn  Count
# 0      AGT         Hypertension,_essential,_susceptibility_to      1
# 1      AGT                    Preeclampsia,_susceptibility_to      1
# 3      AGT  Susceptibility_to_progression_to_renal_failure...      1
# 2      AGT                                    Renal_dysplasia     22
# 4    AP4B1             History_of_neurodevelopmental_disorder      7
# 5    AP4B1         Spastic_paraplegia_47,_autosomal_recessive     10
# 9   COL4A1                                 Porencephalic_cyst     17
# 8   COL4A1         Brain_small_vessel_disease_with_hemorrhage     26
# 7   COL4A1  Brain_small_vessel_disease_1_with_or_without_o...     38
# 6   COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...     40
# 10    IL10           Graft-versus-host_disease,_resistance_to      1
# 11    IL10  Human_immunodeficiency_virus_type_1,_susceptib...      1
# 12    IL10                         Inflammatory_bowel_disease     10
# 13    IL1B                            Antisynthetase_syndrome      1
# 14    IL1B  Gastric_cancer_susceptibility_after_h._pylori_...      1
# 15     IL6  Crohn_disease-associated_growth_failure,_susce...      1
# 16     IL6       Diabetes_mellitus,_type_1,_susceptibility_to      1
# 17     IL6        Diabetes_mellitus_type_2,_susceptibility_to      1
# 18     IL6                         INTERLEUKIN_6_POLYMORPHISM      1
# 19     IL6  Intracranial_hemorrhage_in_brain_cerebrovascul...      1
# 20     IL6                                     Kaposi_sarcoma      1
# 21     IL6  Rheumatoid_arthritis,_systemic_juvenile,_susce...      1
# 25   MTHFR                            Intellectual_disability      1
# 27   MTHFR                                Neoplasm_of_stomach      1
# 29   MTHFR                                      Schizophrenia      1
# 30   MTHFR                   Schizophrenia,_susceptibility_to      1
# 32   MTHFR                    carboplatin_response_-_Efficacy      1
# 33   MTHFR           cyclophosphamide_response_-_Toxicity/ADR      1
# 34   MTHFR  methotrexate_response_-_Dosage,_Efficacy,_Toxi...      1
# 22   MTHFR                     Gastrointestinal_stromal_tumor      2
# 26   MTHFR                MTHFR_deficiency,_thermolabile_type      2
# 31   MTHFR               Thrombophilia_due_to_thrombin_defect      2
# 28   MTHFR              Neural_tube_defects,_folate-sensitive      7
# 23   MTHFR             Homocystinuria_due_to_MTHFR_deficiency     13
# 24   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...     39
# 35    NOS3   Alzheimer_disease,_late-onset,_susceptibility_to      1
# 36    NOS3         Coronary_artery_spasm_1,_susceptibility_to      1
# 37    NOS3  Hypertension,_pregnancy-induced,_susceptibilit...      1
# 38    NOS3     Hypertension_resistant_to_conventional_therapy      1
# 39    NOS3          Ischemic_heart_disease,_susceptibility_to      1
# 40    NOS3                 Ischemic_stroke,_susceptibility_to      1
# 41    NOS3              Metabolic_syndrome,_susceptibility_to      1

# %% [markdown]
# ### Combine information on variants associated with HIE and variants associated with diseases in ClinVar databases

# %%
# Concatenate information on variants with known ClinVar phenotypes and HIE associations. Drop duplicate information.

variants_with_known_phenotypes = pd.concat([variants_with_ClinVar_phenotypes, variants_with_hie_assoc]).drop_duplicates()

variants_with_known_phenotypes.VAR_NAME.nunique()
# Out:
# 137

# %% [markdown]
# ### How many of the variants with known disease phenotypes (ClinVar and HIE studies) have predicted deleteriousness (CADD>=10)?

# %%
# Join the phenotype and cadd data

variants_phenotypes_and_cadd_phred = pd.merge(variants_with_known_phenotypes, vep_data, how='left', on=['ID','CHROM','POS','REF','ALT','GENE'])

# %%
# Filter for variants with cadd >=10

deleterious_variants_with_known_phenotype = variants_phenotypes_and_cadd_phred[variants_phenotypes_and_cadd_phred.CADD_PHRED_SCORE >= 10]

# %%
# Count the number of variants with known disease phenotypes and cadd >= 10

deleterious_variants_with_known_phenotype.ID.nunique()
# Out:
# 41

# %%
# Percentage of variants with known disease phenotypes and cadd >= 10 of the variants with known disease phenotypes

(deleterious_variants_with_known_phenotype.ID.nunique()/variants_with_known_phenotypes['ID'].nunique())*100
# Out:
# 29.927007299270077

# %% [markdown]
# What phenotypes are represented in the variants with cadd scores >= 10?

# %%
deleterious_variants_with_known_phenotype_grouped_by_gene = deleterious_variants_with_known_phenotype[['GENE','Clndn','ID']].groupby(['GENE','Clndn']).count().reset_index().sort_values(by=['GENE','ID'], ascending=True)
deleterious_variants_with_known_phenotype_grouped_by_gene.rename(columns={'ID':'Count'}, inplace=True)

deleterious_variants_with_known_phenotype_grouped_by_gene
# Out:
#       GENE                                              Clndn  Count
# 0      AGT                                    Renal_dysplasia      5
# 3    AP4B1  Spastic_paraplegia_47,_autosomal_recessive|His...      1
# 1    AP4B1             History_of_neurodevelopmental_disorder      5
# 2    AP4B1         Spastic_paraplegia_47,_autosomal_recessive      7
# 6   COL4A1         Brain_small_vessel_disease_with_hemorrhage      3
# 5   COL4A1  Brain_small_vessel_disease_1_with_or_without_o...      5
# 7   COL4A1                                 Porencephalic_cyst      5
# 4   COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...      6
# 8     IL10                         Inflammatory_bowel_disease      5
# 9     IL1B  Gastric_cancer_susceptibility_after_h._pylori_...      1
# 10     IL6  Crohn_disease-associated_growth_failure,_susce...      1
# 11     IL6       Diabetes_mellitus,_type_1,_susceptibility_to      1
# 12     IL6        Diabetes_mellitus_type_2,_susceptibility_to      1
# 13     IL6  Diabetes_mellitus_type_2,_susceptibility_to|Di...      1
# 14     IL6  Intracranial_hemorrhage_in_brain_cerebrovascul...      1
# 15     IL6                                     Kaposi_sarcoma      1
# 16     IL6  Rheumatoid_arthritis,_systemic_juvenile,_susce...      1
# 20   MTHFR                            Intellectual_disability      1
# 22   MTHFR                                Neoplasm_of_stomach      1
# 23   MTHFR  Neoplasm_of_stomach|Gastrointestinal_stromal_t...      1
# 25   MTHFR                                      Schizophrenia      1
# 26   MTHFR                   Schizophrenia,_susceptibility_to      1
# 28   MTHFR                    carboplatin_response_-_Efficacy      1
# 29   MTHFR           cyclophosphamide_response_-_Toxicity/ADR      1
# 30   MTHFR  methotrexate_response_-_Dosage,_Efficacy,_Toxi...      1
# 17   MTHFR                     Gastrointestinal_stromal_tumor      2
# 21   MTHFR                MTHFR_deficiency,_thermolabile_type      2
# 27   MTHFR               Thrombophilia_due_to_thrombin_defect      2
# 24   MTHFR              Neural_tube_defects,_folate-sensitive      3
# 18   MTHFR             Homocystinuria_due_to_MTHFR_deficiency      5
# 19   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...     13
# 31    NOS3   Alzheimer_disease,_late-onset,_susceptibility_to      1
# 32    NOS3         Coronary_artery_spasm_1,_susceptibility_to      1
# 33    NOS3  Hypertension,_pregnancy-induced,_susceptibilit...      1
# 34    NOS3     Hypertension_resistant_to_conventional_therapy      1
# 35    NOS3          Ischemic_heart_disease,_susceptibility_to      1
# 36    NOS3                 Ischemic_stroke,_susceptibility_to      1

# %%
deleterious_variants_with_known_phenotype[deleterious_variants_with_known_phenotype.VAR_NAME.isin(hie_variant_rsids)].ID.nunique()
# Out:
# 3

# %%
deleterious_variants_with_known_phenotype[deleterious_variants_with_known_phenotype.VAR_NAME.isin(hie_variant_rsids)].VAR_NAME.unique()
# Out:
# array(['rs1217401', 'rs1801133', 'rs1800795'], dtype=object)

# %% [markdown]
# ### What are the known phenotypes of the variants with cadd phred scores >= 10 and common frequencies (>0.1)?

# %%
# Display common variants, and their associated clinical disease phenotype

common_deleterious_variants_with_known_phenotype = deleterious_variants_with_known_phenotype[deleterious_variants_with_known_phenotype.IH_AF>=0.1][['GENE','Clndn','ID','VAR_NAME','REF','ALT','IH_AF','CADD_PHRED_SCORE']].sort_values(by=['GENE','Clndn','ID'], ascending=True)
common_deleterious_variants_with_known_phenotype
# Out:
#        GENE                                              Clndn             ID  \
# 125   AP4B1             History_of_neurodevelopmental_disorder  113896329_A_G
# 124   AP4B1         Spastic_paraplegia_47,_autosomal_recessive  113896329_A_G
# 264   AP4B1  Spastic_paraplegia_47,_autosomal_recessive|His...  113896329_A_G
# 8    COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...  110149776_G_T
# 83   COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...  110205548_A_G
# 116  COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...  110307009_C_G
# 120  COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...  110307117_C_A
# 7    COL4A1  Brain_small_vessel_disease_1_with_or_without_o...  110149776_G_T
# 82   COL4A1  Brain_small_vessel_disease_1_with_or_without_o...  110205548_A_G
# 115  COL4A1  Brain_small_vessel_disease_1_with_or_without_o...  110307009_C_G
# 119  COL4A1  Brain_small_vessel_disease_1_with_or_without_o...  110307117_C_A
# 117  COL4A1         Brain_small_vessel_disease_with_hemorrhage  110307009_C_G
# 6    COL4A1                                 Porencephalic_cyst  110149776_G_T
# 81   COL4A1                                 Porencephalic_cyst  110205548_A_G
# 114  COL4A1                                 Porencephalic_cyst  110307009_C_G
# 118  COL4A1                                 Porencephalic_cyst  110307117_C_A
# 224    IL10                         Inflammatory_bowel_disease  206771300_T_C
# 122    IL1B  Gastric_cancer_susceptibility_after_h._pylori_...  112836810_G_A
# 237     IL6  Crohn_disease-associated_growth_failure,_susce...   22727026_C_G
# 233     IL6       Diabetes_mellitus,_type_1,_susceptibility_to   22727026_C_G
# 232     IL6        Diabetes_mellitus_type_2,_susceptibility_to   22727026_C_G
# 268     IL6  Diabetes_mellitus_type_2,_susceptibility_to|Di...   22727026_C_G
# 234     IL6  Intracranial_hemorrhage_in_brain_cerebrovascul...   22727026_C_G
# 236     IL6                                     Kaposi_sarcoma   22727026_C_G
# 235     IL6  Rheumatoid_arthritis,_systemic_juvenile,_susce...   22727026_C_G
# 169   MTHFR                     Gastrointestinal_stromal_tumor   11794419_T_G
# 173   MTHFR             Homocystinuria_due_to_MTHFR_deficiency   11794419_T_G
# 170   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...   11794419_T_G
# 172   MTHFR                MTHFR_deficiency,_thermolabile_type   11794419_T_G
# 171   MTHFR              Neural_tube_defects,_folate-sensitive   11794419_T_G
# 168   MTHFR                   Schizophrenia,_susceptibility_to   11794419_T_G
# 215    NOS3   Alzheimer_disease,_late-onset,_susceptibility_to  150999023_T_G
# 218    NOS3         Coronary_artery_spasm_1,_susceptibility_to  150999023_T_G
# 216    NOS3  Hypertension,_pregnancy-induced,_susceptibilit...  150999023_T_G
# 217    NOS3     Hypertension_resistant_to_conventional_therapy  150999023_T_G
# 213    NOS3          Ischemic_heart_disease,_susceptibility_to  150999023_T_G
# 214    NOS3                 Ischemic_stroke,_susceptibility_to  150999023_T_G
#
#         VAR_NAME REF ALT     IH_AF  CADD_PHRED_SCORE
# 125    rs1217401   A   G  0.797541             21.90
# 124    rs1217401   A   G  0.797541             21.90
# 264    rs1217401   A   G  0.797541             21.90
# 8        rs13260   G   T  0.266393             11.67
# 83      rs677877   A   G  0.388060             10.31
# 116    rs9515185   C   G  0.216172             13.89
# 120  rs113651836   C   A  0.107084             14.63
# 7        rs13260   G   T  0.266393             11.67
# 82      rs677877   A   G  0.388060             10.31
# 115    rs9515185   C   G  0.216172             13.89
# 119  rs113651836   C   A  0.107084             14.63
# 117    rs9515185   C   G  0.216172             13.89
# 6        rs13260   G   T  0.266393             11.67
# 81      rs677877   A   G  0.388060             10.31
# 114    rs9515185   C   G  0.216172             13.89
# 118  rs113651836   C   A  0.107084             14.63
# 224    rs1518111   T   C  0.555738             10.64
# 122    rs1143627   G   A  0.351639             10.26
# 237    rs1800795   C   G  0.999180             18.77
# 233    rs1800795   C   G  0.999180             18.77
# 232    rs1800795   C   G  0.999180             18.77
# 268    rs1800795   C   G  0.999180             18.77
# 234    rs1800795   C   G  0.999180             18.77
# 236    rs1800795   C   G  0.999180             18.77
# 235    rs1800795   C   G  0.999180             18.77
# 169    rs1801131   T   G  0.145902             20.90
# 173    rs1801131   T   G  0.145902             20.90
# 170    rs1801131   T   G  0.145902             20.90
# 172    rs1801131   T   G  0.145902             20.90
# 171    rs1801131   T   G  0.145902             20.90
# 168    rs1801131   T   G  0.145902             20.90
# 215    rs1799983   T   G  0.935246             10.07
# 218    rs1799983   T   G  0.935246             10.07
# 216    rs1799983   T   G  0.935246             10.07
# 217    rs1799983   T   G  0.935246             10.07
# 213    rs1799983   T   G  0.935246             10.07
# 214    rs1799983   T   G  0.935246             10.07

# %%
# Count the number of variants with known phenotypes, CADD >=10 and that are common

common_deleterious_variants_with_known_phenotype.ID.nunique()
# Out:
# 10

# %% [markdown]
# ### How do the frequencies of the common variants with known phenotypes and CADD Phred scores in Africans >=10 compare to that of other global populations?

# %%
# Add ALFA global allele count data to African data in common_deleterious_variants_with_known_phenotype dataframe

common_deleterious_variants_with_known_phenotype_incl_alfa = pd.merge(common_deleterious_variants_with_known_phenotype.drop_duplicates(subset=['VAR_NAME','REF','ALT']).drop(columns=['Clndn','ID','CADD_PHRED_SCORE']), alfa_global, how='left', left_on=['VAR_NAME','REF','ALT'], right_on=['variant_id','reference_allele','alternate_allele'])
common_deleterious_variants_with_known_phenotype_incl_alfa = common_deleterious_variants_with_known_phenotype_incl_alfa.drop(columns=['variant_id','reference_allele','alternate_allele'])

# %%
# Calculate the alternate allele frequencies for the global populations

common_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_East Asian'] = common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_East Asian']/(common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_East Asian']+common_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_East Asian'])
common_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_South Asian'] = common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_South Asian']/(common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_South Asian']+common_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_South Asian'])
common_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_European'] = common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_European']/(common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_European']+common_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_European'])
common_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_Latin American 1'] = common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 1']/(common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 1']+common_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_Latin American 1'])
common_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_Latin American 2'] = common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 2']/(common_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 2']+common_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_Latin American 2'])

common_deleterious_variants_with_known_phenotype_incl_alfa.drop(columns=['ALT_CT_ALFA_East Asian','ALT_CT_ALFA_South Asian','ALT_CT_ALFA_European','ALT_CT_ALFA_Latin American 1','ALT_CT_ALFA_Latin American 2','REF_CT_ALFA_East Asian','REF_CT_ALFA_South Asian','REF_CT_ALFA_European','REF_CT_ALFA_Latin American 1','REF_CT_ALFA_Latin American 2'], inplace=True)
common_deleterious_variants_with_known_phenotype_incl_alfa
# Out:
#      GENE     VAR_NAME REF ALT     IH_AF  ALFA_AF_East Asian  \
# 0   AP4B1    rs1217401   A   G  0.797541            0.057899
# 1  COL4A1      rs13260   G   T  0.266393            0.004016
# 2  COL4A1     rs677877   A   G  0.388060            0.758065
# 3  COL4A1    rs9515185   C   G  0.216172            0.488372
# 4  COL4A1  rs113651836   C   A  0.107084            0.026316
# 5    IL10    rs1518111   T   C  0.555738            0.295049
# 6    IL1B    rs1143627   G   A  0.351639            0.505700
# 7     IL6    rs1800795   C   G  0.999180            1.000000
# 8   MTHFR    rs1801131   T   G  0.145902            0.214497
# 9    NOS3    rs1799983   T   G  0.935246            0.857143
#
#    ALFA_AF_South Asian  ALFA_AF_European  ALFA_AF_Latin American 1  \
# 0             0.327415          0.321924                  0.419217
# 1             0.039773          0.091209                  0.130312
# 2             0.660000          0.641808                  0.613095
# 3             0.489796          0.406679                  0.493151
# 4             0.000000          0.197838                  0.000000
# 5             0.603571          0.784843                  0.734914
# 6             0.415344          0.664999                  0.585017
# 7             0.857143          0.559989                  0.828767
# 8             0.410439          0.314106                  0.219092
# 9             0.333333          0.679167                  0.763889
#
#    ALFA_AF_Latin American 2
# 0                  0.192529
# 1                  0.226508
# 2                  0.550746
# 3                  0.372131
# 4                  0.000000
# 5                  0.661386
# 6                  0.445177
# 7                  0.819672
# 8                  0.192032
# 9                  0.240000

# %% [markdown]
# ### What are the frequencies of the common variants with known phenotypes and CADD Phred scores >=10 in each African ethnolinguistic population group?

# %%
# Get a list of variants to get frequencies for.

common_deleterious_variants_with_known_phenotype_list = list(common_deleterious_variants_with_known_phenotype.ID.unique())

# %%
# Extract ethnolinguistic population frequencies for each of these variants. 

ih_afr_subpops_common_deleterious_variants = ih_afr[(ih_afr.ID.isin(common_deleterious_variants_with_known_phenotype_list)) & ~ (ih_afr.REG == 'Recent African')]

# %%
# Filter out irrelevant data. Pivot data.

ih_afr_subpops_common_deleterious_variants_filtered = ih_afr_subpops_common_deleterious_variants.drop(columns=['POS','REF','ALT','IH_ALT_CTS','IH_TOTAL_CTS','IH_REF_CTS','VARIANT_TYPE','REG'])
ih_afr_subpops_common_deleterious_variants_filtered = ih_afr_subpops_common_deleterious_variants_filtered.pivot(index=['ID','VAR_NAME','GENE'], columns=['SUB_POP'], values=['IH_AF']).reset_index()

# %%
# Add overall African frequencies

ih_afr_subpops_common_deleterious_variants_filtered = pd.merge(left=common_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_common_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
ih_afr_subpops_common_deleterious_variants_filtered
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2872\3809755307.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   ih_afr_subpops_common_deleterious_variants_filtered = pd.merge(left=common_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_common_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
# C:\Users\User\AppData\Local\Temp\ipykernel_2872\3809755307.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ih_afr_subpops_common_deleterious_variants_filtered = pd.merge(left=common_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_common_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
#       VAR_NAME     IH_AF         (ID, ) (GENE, )  (IH_AF, Bantu Kenya)  \
# 0    rs1217401  0.797541  113896329_A_G    AP4B1                  0.75
# 1      rs13260  0.266393  110149776_G_T   COL4A1                  0.40
# 2     rs677877  0.388060  110205548_A_G   COL4A1                  0.55
# 3    rs9515185  0.216172  110307009_C_G   COL4A1                  0.15
# 4  rs113651836  0.107084  110307117_C_A   COL4A1                  0.05
# 5    rs1518111  0.555738  206771300_T_C     IL10                  0.70
# 6    rs1143627  0.351639  112836810_G_A     IL1B                  0.30
# 7    rs1800795  0.999180   22727026_C_G      IL6                  1.00
# 8    rs1801131  0.145902   11794419_T_G    MTHFR                  0.10
# 9    rs1799983  0.935246  150999023_T_G     NOS3                  0.90
#
#    (IH_AF, Bantu South Africa)  (IH_AF, Biaka Pygmy)  (IH_AF, Esan)  \
# 0                     0.812500              0.568182       0.815534
# 1                     0.312500              0.454545       0.271845
# 2                     0.285714              0.318182       0.388350
# 3                     0.125000              0.204545       0.169903
# 4                     0.000000              0.090909       0.169903
# 5                     0.687500              0.681818       0.533981
# 6                     0.187500              0.340909       0.359223
# 7                     1.000000              1.000000       1.000000
# 8                     0.250000              0.386364       0.135922
# 9                     1.000000              0.931818       0.898058
#
#    (IH_AF, Luhya)  (IH_AF, Mandenka)  (IH_AF, Mandinka)  (IH_AF, Mbuti Pygmy)  \
# 0        0.788043           0.950000           0.831897              0.291667
# 1        0.320652           0.150000           0.206897              0.166667
# 2        0.384615           0.550000           0.448276              0.041667
# 3        0.157609           0.236842           0.327586              0.458333
# 4        0.097826           0.131579           0.081897              0.041667
# 5        0.608696           0.450000           0.534483              0.750000
# 6        0.277174           0.550000           0.426724              0.333333
# 7        1.000000           1.000000           0.995690              1.000000
# 8        0.184783           0.025000           0.120690              0.166667
# 9        0.961957           0.950000           0.922414              1.000000
#
#    (IH_AF, Mende)  (IH_AF, San)  (IH_AF, Yoruba)
# 0        0.777108      0.666667         0.840580
# 1        0.265060      0.000000         0.271739
# 2        0.353659      0.166667         0.380597
# 3        0.265060      0.200000         0.154412
# 4        0.066265      0.000000         0.131387
# 5        0.512048      0.916667         0.525362
# 6        0.319277      0.166667         0.347826
# 7        1.000000      1.000000         1.000000
# 8        0.138554      0.333333         0.119565
# 9        0.951807      0.583333         0.952899

# %% [markdown]
# ### What are the known phenotypes of the variants with cadd phred scores >= 10 and rare frequencies (>=0.01)?

# %%
# Display rare variants, and their associated clinical disease phenotype

rare_deleterious_variants_with_known_phenotype = deleterious_variants_with_known_phenotype[deleterious_variants_with_known_phenotype.IH_AF<=0.01][['GENE','Clndn','ID','VAR_NAME','REF','ALT','IH_AF','CADD_PHRED_SCORE']].sort_values(by=['GENE','Clndn','ID'], ascending=True)
rare_deleterious_variants_with_known_phenotype
# Out:
#        GENE                                              Clndn  \
# 245     AGT                                    Renal_dysplasia
# 246     AGT                                    Renal_dysplasia
# 247     AGT                                    Renal_dysplasia
# 251     AGT                                    Renal_dysplasia
# 126   AP4B1             History_of_neurodevelopmental_disorder
# 129   AP4B1             History_of_neurodevelopmental_disorder
# 131   AP4B1             History_of_neurodevelopmental_disorder
# 123   AP4B1         Spastic_paraplegia_47,_autosomal_recessive
# 128   AP4B1         Spastic_paraplegia_47,_autosomal_recessive
# 130   AP4B1         Spastic_paraplegia_47,_autosomal_recessive
# 137   AP4B1         Spastic_paraplegia_47,_autosomal_recessive
# 4    COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...
# 85   COL4A1  Angiopathy,_hereditary,_with_nephropathy,_aneu...
# 84   COL4A1  Brain_small_vessel_disease_1_with_or_without_o...
# 5    COL4A1         Brain_small_vessel_disease_with_hemorrhage
# 3    COL4A1                                 Porencephalic_cyst
# 219    IL10                         Inflammatory_bowel_disease
# 223    IL10                         Inflammatory_bowel_disease
# 226    IL10                         Inflammatory_bowel_disease
# 192   MTHFR             Homocystinuria_due_to_MTHFR_deficiency
# 152   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 156   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 178   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 185   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 187   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 191   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 193   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 208   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 211   MTHFR  Homocystinuria_due_to_methylene_tetrahydrofola...
# 157   MTHFR              Neural_tube_defects,_folate-sensitive
# 154   MTHFR                                      Schizophrenia
# 155   MTHFR               Thrombophilia_due_to_thrombin_defect
#
#                   ID              VAR_NAME REF  ALT     IH_AF  \
# 245    230703157_G_A           rs143479528   G    A  0.004098
# 246    230703274_G_A            rs61751077   G    A  0.005738
# 247    230704308_A_G            rs61731499   A    G  0.006557
# 251    230706171_C_T           rs139685563   C    T  0.001639
# 126    113897925_C_T           rs145803736   C    T  0.000820
# 129    113900051_A_T           rs149335605   A    T  0.000820
# 131    113900120_C_A           rs111785152   C    A  0.008197
# 123    113895442_A_C           rs148748734   A    C  0.001639
# 128    113900051_A_T           rs149335605   A    T  0.000820
# 130    113900120_C_A           rs111785152   C    A  0.008197
# 137    113901851_T_C           rs143769705   T    C  0.000820
# 4    110149715_A_AAT  chr13:110149715A-AAT   A  AAT  0.000825
# 85     110206692_T_C           rs140978802   T    C  0.001639
# 84     110206692_T_C           rs140978802   T    C  0.001639
# 5    110149715_A_AAT  chr13:110149715A-AAT   A  AAT  0.000825
# 3    110149715_A_AAT  chr13:110149715A-AAT   A  AAT  0.000825
# 219    206768666_T_G           rs568879359   T    G  0.001642
# 223    206771057_A_G           rs139352858   A    G  0.001639
# 226    206772380_C_T           rs139073251   C    T  0.000820
# 192     11796278_G_A            rs34279942   G    A  0.005738
# 152     11792285_T_G           rs145641996   T    G  0.001639
# 156     11792354_C_A            rs45449298   C    A  0.004918
# 178     11794442_C_G           rs200688214   C    G  0.001639
# 185     11795125_C_T           rs543016186   C    T  0.000820
# 187     11795341_T_G           rs142612062   T    G  0.006557
# 191     11796278_G_A            rs34279942   G    A  0.005738
# 193     11796319_C_T           rs150847674   C    T  0.001639
# 208     11802878_T_C             rs1413355   T    C  0.007377
# 211     11806126_C_T            rs13306560   C    T  0.001642
# 157     11792354_C_A            rs45449298   C    A  0.004918
# 154     11792354_C_A            rs45449298   C    A  0.004918
# 155     11792354_C_A            rs45449298   C    A  0.004918
#
#      CADD_PHRED_SCORE
# 245             24.50
# 246             23.50
# 247             11.45
# 251             22.90
# 126             25.90
# 129             22.00
# 131             20.70
# 123             12.93
# 128             22.00
# 130             20.70
# 137             14.07
# 4               13.42
# 85              10.91
# 84              10.91
# 5               13.42
# 3               13.42
# 219             24.30
# 223             17.60
# 226             14.57
# 192             10.02
# 152             23.00
# 156             22.00
# 178             27.80
# 185             24.10
# 187             22.70
# 191             10.02
# 193             22.90
# 208             19.93
# 211             20.30
# 157             22.00
# 154             22.00
# 155             22.00

# %%
# Count the number of variants with known phenotypes, CADD >=10 and that are common

rare_deleterious_variants_with_known_phenotype.ID.nunique()
# Out:
# 23

# %% [markdown]
# ### How do the frequencies of the rare variants with known phenotypes and CADD Phred scores in Africans >=10 compare to that of other global populations?

# %%
# Add ALFA global allele count data to African data in rare_deleterious_variants_with_known_phenotype dataframe

rare_deleterious_variants_with_known_phenotype_incl_alfa = pd.merge(rare_deleterious_variants_with_known_phenotype.drop_duplicates(subset=['VAR_NAME','REF','ALT']).drop(columns=['Clndn','ID','CADD_PHRED_SCORE']), alfa_global, how='left', left_on=['VAR_NAME','REF','ALT'], right_on=['variant_id','reference_allele','alternate_allele'])
rare_deleterious_variants_with_known_phenotype_incl_alfa = rare_deleterious_variants_with_known_phenotype_incl_alfa.drop(columns=['variant_id','reference_allele','alternate_allele'])

# %%
# Calculate the alternate allele frequencies for the global populations

rare_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_East Asian'] = rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_East Asian']/(rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_East Asian']+rare_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_East Asian'])
rare_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_South Asian'] = rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_South Asian']/(rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_South Asian']+rare_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_South Asian'])
rare_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_European'] = rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_European']/(rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_European']+rare_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_European'])
rare_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_Latin American 1'] = rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 1']/(rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 1']+rare_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_Latin American 1'])
rare_deleterious_variants_with_known_phenotype_incl_alfa['ALFA_AF_Latin American 2'] = rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 2']/(rare_deleterious_variants_with_known_phenotype_incl_alfa['ALT_CT_ALFA_Latin American 2']+rare_deleterious_variants_with_known_phenotype_incl_alfa['REF_CT_ALFA_Latin American 2'])

rare_deleterious_variants_with_known_phenotype_incl_alfa.drop(columns=['ALT_CT_ALFA_East Asian','ALT_CT_ALFA_South Asian','ALT_CT_ALFA_European','ALT_CT_ALFA_Latin American 1','ALT_CT_ALFA_Latin American 2','REF_CT_ALFA_East Asian','REF_CT_ALFA_South Asian','REF_CT_ALFA_European','REF_CT_ALFA_Latin American 1','REF_CT_ALFA_Latin American 2'], inplace=True)
rare_deleterious_variants_with_known_phenotype_incl_alfa
# Out:
#       GENE              VAR_NAME REF  ALT     IH_AF  ALFA_AF_East Asian  \
# 0      AGT           rs143479528   G    A  0.004098            0.000000
# 1      AGT            rs61751077   G    A  0.005738            0.000000
# 2      AGT            rs61731499   A    G  0.006557            0.000000
# 3      AGT           rs139685563   C    T  0.001639            0.000000
# 4    AP4B1           rs145803736   C    T  0.000820            0.000000
# 5    AP4B1           rs149335605   A    T  0.000820            0.000000
# 6    AP4B1           rs111785152   C    A  0.008197            0.000000
# 7    AP4B1           rs148748734   A    C  0.001639            0.000000
# 8    AP4B1           rs143769705   T    C  0.000820            0.000000
# 9   COL4A1  chr13:110149715A-AAT   A  AAT  0.000825                 NaN
# 10  COL4A1           rs140978802   T    C  0.001639            0.000000
# 11    IL10           rs568879359   T    G  0.001642            0.000000
# 12    IL10           rs139352858   A    G  0.001639            0.000000
# 13    IL10           rs139073251   C    T  0.000820            0.000000
# 14   MTHFR            rs34279942   G    A  0.005738            0.000000
# 15   MTHFR           rs145641996   T    G  0.001639            0.000000
# 16   MTHFR            rs45449298   C    A  0.004918            0.000000
# 17   MTHFR           rs200688214   C    G  0.001639            0.000000
# 18   MTHFR           rs543016186   C    T  0.000820            0.000000
# 19   MTHFR           rs142612062   T    G  0.006557            0.000000
# 20   MTHFR           rs150847674   C    T  0.001639            0.000000
# 21   MTHFR             rs1413355   T    C  0.007377            0.007538
# 22   MTHFR            rs13306560   C    T  0.001642            0.001894
#
#     ALFA_AF_South Asian  ALFA_AF_European  ALFA_AF_Latin American 1  \
# 0              0.000000          0.000006                  0.000000
# 1              0.000000          0.000013                  0.000000
# 2              0.000000          0.000026                  0.004926
# 3              0.000000          0.000509                  0.001256
# 4              0.000000          0.000033                  0.000000
# 5              0.000000          0.000000                  0.000000
# 6              0.000000          0.000010                  0.003953
# 7              0.000000          0.000000                  0.000000
# 8              0.000000          0.000000                  0.000000
# 9                   NaN               NaN                       NaN
# 10             0.000000          0.000000                  0.000000
# 11             0.000000          0.000000                  0.000000
# 12             0.000000          0.000000                  0.000000
# 13             0.000000          0.000062                  0.000000
# 14             0.000000          0.000441                  0.001969
# 15             0.000000          0.000023                  0.002008
# 16             0.000000          0.000331                  0.000000
# 17             0.000000          0.000038                  0.000000
# 18             0.000000          0.000353                  0.000000
# 19             0.000000          0.000000                  0.000000
# 20             0.000000          0.000006                  0.000000
# 21             0.000000          0.000000                  0.000000
# 22             0.039773          0.053909                  0.046575
#
#     ALFA_AF_Latin American 2
# 0                   0.000000
# 1                   0.001053
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# 5                   0.000000
# 6                   0.000000
# 7                   0.000000
# 8                   0.000000
# 9                        NaN
# 10                  0.000000
# 11                  0.000000
# 12                  0.000000
# 13                  0.000000
# 14                  0.000000
# 15                  0.000000
# 16                  0.000000
# 17                  0.000000
# 18                  0.000000
# 19                  0.000000
# 20                  0.000000
# 21                  0.000000
# 22                  0.024429

# %% [markdown]
# ### What are the frequencies of the rare variants with known phenotypes and CADD Phred scores >=10 in each African ethnolinguistic population group?

# %%
# Get a list of variants to get frequencies for.

rare_deleterious_variants_with_known_phenotype_list = list(rare_deleterious_variants_with_known_phenotype.ID.unique())

# %%
# Extract ethnolinguistic population frequencies for each of these variants. 

ih_afr_subpops_rare_deleterious_variants = ih_afr[(ih_afr.ID.isin(rare_deleterious_variants_with_known_phenotype_list)) & ~ (ih_afr.REG == 'Recent African')]

# %%
# Filter out irrelevant data. Pivot data.

ih_afr_subpops_rare_deleterious_variants_filtered = ih_afr_subpops_rare_deleterious_variants.drop(columns=['POS','REF','ALT','IH_ALT_CTS','IH_TOTAL_CTS','IH_REF_CTS','VARIANT_TYPE','REG'])
ih_afr_subpops_rare_deleterious_variants_filtered = ih_afr_subpops_rare_deleterious_variants_filtered.pivot(index=['ID','VAR_NAME','GENE'], columns=['SUB_POP'], values=['IH_AF']).reset_index()

# %%
# Add overall African frequencies

ih_afr_subpops_rare_deleterious_variants_filtered = pd.merge(left=rare_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_rare_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
ih_afr_subpops_rare_deleterious_variants_filtered
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2872\320947548.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   ih_afr_subpops_rare_deleterious_variants_filtered = pd.merge(left=rare_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_rare_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
# C:\Users\User\AppData\Local\Temp\ipykernel_2872\320947548.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   ih_afr_subpops_rare_deleterious_variants_filtered = pd.merge(left=rare_deleterious_variants_with_known_phenotype_incl_alfa[['VAR_NAME','IH_AF']], right=ih_afr_subpops_rare_deleterious_variants_filtered, how='left', on=['VAR_NAME'])
#                 VAR_NAME     IH_AF           (ID, ) (GENE, )  \
# 0            rs143479528  0.004098    230703157_G_A      AGT
# 1             rs61751077  0.005738    230703274_G_A      AGT
# 2             rs61731499  0.006557    230704308_A_G      AGT
# 3            rs139685563  0.001639    230706171_C_T      AGT
# 4            rs145803736  0.000820    113897925_C_T    AP4B1
# 5            rs149335605  0.000820    113900051_A_T    AP4B1
# 6            rs111785152  0.008197    113900120_C_A    AP4B1
# 7            rs148748734  0.001639    113895442_A_C    AP4B1
# 8            rs143769705  0.000820    113901851_T_C    AP4B1
# 9   chr13:110149715A-AAT  0.000825  110149715_A_AAT   COL4A1
# 10           rs140978802  0.001639    110206692_T_C   COL4A1
# 11           rs568879359  0.001642    206768666_T_G     IL10
# 12           rs139352858  0.001639    206771057_A_G     IL10
# 13           rs139073251  0.000820    206772380_C_T     IL10
# 14            rs34279942  0.005738     11796278_G_A    MTHFR
# 15           rs145641996  0.001639     11792285_T_G    MTHFR
# 16            rs45449298  0.004918     11792354_C_A    MTHFR
# 17           rs200688214  0.001639     11794442_C_G    MTHFR
# 18           rs543016186  0.000820     11795125_C_T    MTHFR
# 19           rs142612062  0.006557     11795341_T_G    MTHFR
# 20           rs150847674  0.001639     11796319_C_T    MTHFR
# 21             rs1413355  0.007377     11802878_T_C    MTHFR
# 22            rs13306560  0.001642     11806126_C_T    MTHFR
#
#     (IH_AF, Bantu Kenya)  (IH_AF, Bantu South Africa)  (IH_AF, Biaka Pygmy)  \
# 0                   0.00                          0.0                   0.0
# 1                   0.00                          0.0                   0.0
# 2                   0.05                          0.0                   0.0
# 3                   0.00                          0.0                   0.0
# 4                   0.00                          0.0                   0.0
# 5                   0.00                          0.0                   0.0
# 6                   0.00                          0.0                   0.0
# 7                   0.00                          0.0                   0.0
# 8                   0.00                          0.0                   0.0
# 9                   0.00                          0.0                   0.0
# 10                  0.00                          0.0                   0.0
# 11                  0.00                          0.0                   0.0
# 12                  0.00                          0.0                   0.0
# 13                  0.00                          0.0                   0.0
# 14                  0.00                          0.0                   0.0
# 15                  0.00                          0.0                   0.0
# 16                  0.00                          0.0                   0.0
# 17                  0.05                          0.0                   0.0
# 18                  0.00                          0.0                   0.0
# 19                  0.00                          0.0                   0.0
# 20                  0.00                          0.0                   0.0
# 21                  0.10                          0.0                   0.0
# 22                  0.00                          0.0                   0.0
#
#     (IH_AF, Esan)  (IH_AF, Luhya)  (IH_AF, Mandenka)  (IH_AF, Mandinka)  \
# 0        0.014563        0.000000               0.00           0.000000
# 1        0.000000        0.000000               0.00           0.008621
# 2        0.000000        0.021739               0.00           0.000000
# 3        0.000000        0.010870               0.00           0.000000
# 4        0.000000        0.005435               0.00           0.000000
# 5        0.000000        0.005435               0.00           0.000000
# 6        0.000000        0.005435               0.00           0.025862
# 7        0.004854        0.000000               0.00           0.000000
# 8        0.000000        0.000000               0.00           0.000000
# 9        0.000000        0.000000               0.00           0.000000
# 10       0.000000        0.000000               0.00           0.008621
# 11       0.000000        0.000000               0.00           0.000000
# 12       0.004854        0.000000               0.00           0.000000
# 13       0.000000        0.000000               0.00           0.004310
# 14       0.000000        0.027174               0.00           0.000000
# 15       0.000000        0.000000               0.00           0.000000
# 16       0.004854        0.016304               0.00           0.000000
# 17       0.000000        0.005435               0.00           0.000000
# 18       0.004854        0.000000               0.00           0.000000
# 19       0.000000        0.000000               0.05           0.021552
# 20       0.009709        0.000000               0.00           0.000000
# 21       0.019417        0.005435               0.00           0.000000
# 22       0.000000        0.000000               0.00           0.008621
#
#     (IH_AF, Mbuti Pygmy)  (IH_AF, Mende)  (IH_AF, San)  (IH_AF, Yoruba)
# 0               0.000000        0.012048      0.000000         0.000000
# 1               0.000000        0.024096      0.000000         0.003623
# 2               0.000000        0.000000      0.083333         0.007246
# 3               0.000000        0.000000      0.000000         0.000000
# 4               0.000000        0.000000      0.000000         0.000000
# 5               0.000000        0.000000      0.000000         0.000000
# 6               0.000000        0.018072      0.000000         0.000000
# 7               0.000000        0.000000      0.000000         0.003623
# 8               0.041667        0.000000      0.000000         0.000000
# 9               0.000000        0.000000      0.000000         0.003623
# 10              0.000000        0.000000      0.000000         0.000000
# 11              0.000000        0.006024      0.000000         0.003623
# 12              0.000000        0.000000      0.000000         0.003623
# 13              0.000000        0.000000      0.000000         0.000000
# 14              0.000000        0.000000      0.000000         0.007246
# 15              0.000000        0.006024      0.000000         0.003623
# 16              0.000000        0.000000      0.000000         0.007246
# 17              0.000000        0.000000      0.000000         0.000000
# 18              0.000000        0.000000      0.000000         0.000000
# 19              0.000000        0.006024      0.000000         0.000000
# 20              0.000000        0.000000      0.000000         0.000000
# 21              0.000000        0.000000      0.000000         0.007246
# 22              0.000000        0.000000      0.000000         0.000000
