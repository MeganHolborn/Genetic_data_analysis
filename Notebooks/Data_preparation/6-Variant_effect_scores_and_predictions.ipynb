# %% [markdown]
# # Preparation of variant effect score data

# %% [markdown]
# Variant effect scores are numerical values or metrics used to quantitatively assess the potential functional impact of genetic variants on genes or proteins. These scores are based on computational predictions which estimate how likely a genetic variant is to have a deleterious (pathogenic) effect.
#
# Genetic variant effect score and prediction data were retrieved for the variants identified in-house from [PredictSNP2](https://loschmidt.chemi.muni.cz/predictsnp2/). The retrieved data is stored at `Data/Raw/PredictSNP2`.
#
# The data was prepared for analysis by:
# 1. Selecting features of interest, such as variant ID, position, reference and alternate allele, and consequence scores and predictions
# 2. Adding additional features including information on the gene in which a particular variant was found

# %% [markdown]
# ## Import libraries and modules

# %%
import os

os.chdir(
    r"C:\Users\User\Desktop\Megan\MSC2\Results\5._Posthoc_analysis\Pipeline_GnomAD_14032023\Notebooks"
)

# %%
import sys

sys.path.append(
    r"C:\Users\User\Desktop\Megan\MSC2\Results\5._Posthoc_analysis\Pipeline_GnomAD_14032023"
)
import pandas as pd
import Utils.constants as constants
import Utils.functions as functions
import numpy as np

# %% [markdown]
# ## Import PredictSNP2 variant effect data

# %%
pdtsnp2_vep_data = pd.DataFrame()
vep_path = os.path.join(
    constants.HOME_PATH, "Data", "Raw", "PredictSNP2", "PredictSNP2.csv"
)
if os.path.exists(vep_path):
    pdtsnp2_vep_data = pd.read_csv(vep_path, sep=";")

pdtsnp2_vep_data.head(5)
# Out:
#    CHROM        POS          ID REF ALT        CONS EXON           SGNF  \
# 0     13  110148891           .   C   G  downstream  NaN              .
# 1     13  110148917  rs59409892   C   G  downstream  NaN              .
# 2     13  110148920           .   G   C  downstream  NaN              .
# 3     13  110148959  rs56406633   A   G        UTR3  NaN  Likely benign
# 4     13  110148971           .   G   C        UTR3  NaN              .
#
#                                                DBSNP  \
# 0                                                  .
# 1  http://www.ncbi.nlm.nih.gov/SNP/snp_ref.cgi?se...
# 2                                                  .
# 3  http://www.ncbi.nlm.nih.gov/SNP/snp_ref.cgi?se...
# 4                                                  .
#
#                                                HAPLO  ... DANNC         FATE  \
# 0                                                  .  ...  0.82      neutral
# 1  http://www.broadinstitute.org/mammals/haploreg...  ...  0.62      neutral
# 2                                                  .  ...  0.65      neutral
# 3  http://www.broadinstitute.org/mammals/haploreg...  ...  0.71  deleterious
# 4                                                  .  ...  0.65  deleterious
#
#       FATS  FATC         FUNE                  FUNS  FUNC   GWAVAE  GWAVAS  \
# 0  0.18997  0.77            .                     .     .  neutral    0.30
# 1  0.18963  0.77      neutral   8.51599164992024E-6  0.80  neutral    0.32
# 2  0.21184  0.75            ?     0.622785975437062  0.49  neutral    0.32
# 3  0.82375  0.82      neutral  7.52439751165574E-20  0.80  neutral    0.44
# 4  0.95264  0.91  deleterious      1.19368630042138  0.74  neutral    0.44
#
#   GWAVAC
# 0   0.68
# 1   0.71
# 2   0.71
# 3   0.53
# 4   0.53
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Select features of interest
# Select variant ID, position, reference and alternate allele, and consequence score and prediction data from various algorithms including FATHMM (FAT), CADD, PredictSNP (PSNP), DANN, FunSeq2 (FUN), and GWAVA.

# %%
pdtsnp2_vep_data = pdtsnp2_vep_data.copy()[
    [
        "CHROM",
        "POS",
        "ID",
        "REF",
        "ALT",
        "SGNF",
        "PSNPE",
        "PSNPS",
        "PSNPC",
        "CADDE",
        "CADDS",
        "CADDC",
        "DANNE",
        "DANNS",
        "DANNC",
        "FATE",
        "FATS",
        "FATC",
        "FUNE",
        "FUNS",
        "FUNC",
        "GWAVAE",
        "GWAVAS",
        "GWAVAC",
    ]
]

pdtsnp2_vep_data.head(5)
# Out:
#    CHROM        POS          ID REF ALT           SGNF        PSNPE     PSNPS  \
# 0     13  110148891           .   C   G              .      neutral -1.000000
# 1     13  110148917  rs59409892   C   G              .      neutral -0.319012
# 2     13  110148920           .   G   C              .      neutral -0.320755
# 3     13  110148959  rs56406633   A   G  Likely benign  deleterious  0.456207
# 4     13  110148971           .   G   C              .      neutral -0.155078
#
#    PSNPC        CADDE  ...  DANNC         FATE     FATS  FATC         FUNE  \
# 0   0.88      neutral  ...   0.82      neutral  0.18997  0.77            .
# 1   0.74  deleterious  ...   0.62      neutral  0.18963  0.77      neutral
# 2   0.74  deleterious  ...   0.65      neutral  0.21184  0.75            ?
# 3   0.91  deleterious  ...   0.71  deleterious  0.82375  0.82      neutral
# 4   0.73      neutral  ...   0.65  deleterious  0.95264  0.91  deleterious
#
#                    FUNS  FUNC   GWAVAE GWAVAS GWAVAC
# 0                     .     .  neutral   0.30   0.68
# 1   8.51599164992024E-6  0.80  neutral   0.32   0.71
# 2     0.622785975437062  0.49  neutral   0.32   0.71
# 3  7.52439751165574E-20  0.80  neutral   0.44   0.53
# 4      1.19368630042138  0.74  neutral   0.44   0.53
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Handle missing values
# Replace missing values, currently represented with decimal points, with Numpy NaN values

# %%
pdtsnp2_vep_data = pdtsnp2_vep_data.replace(".", np.NaN)

# %% [markdown]
# ## Add features
# Add information on the gene in which a particular variant was found

# %%
# Import gene and positional data from CSV file
gene_positional_data = pd.read_csv(
    os.path.join(
        constants.HOME_PATH,
        "Data",
        "Processed",
        "Variant_consequences.csv",
    ),
    usecols=["ID", "REF", "ALT", "POS", "GENE"],
)

# Merge gene and positional data with frequency information
pdtsnp2_vep_data = (
    pdtsnp2_vep_data.merge(
        gene_positional_data,
        how="left",
        on=[
            "POS",
            "REF",
            "ALT",
        ],
    )
    .drop(columns=["ID_x"])
    .rename(columns={"ID_y": "ID"})
)

pdtsnp2_vep_data.head(5)
# Out:
#    CHROM        POS REF ALT           SGNF        PSNPE     PSNPS  PSNPC  \
# 0     13  110148891   C   G            NaN      neutral -1.000000   0.88
# 1     13  110148917   C   G            NaN      neutral -0.319012   0.74
# 2     13  110148920   G   C            NaN      neutral -0.320755   0.74
# 3     13  110148959   A   G  Likely benign  deleterious  0.456207   0.91
# 4     13  110148971   G   C            NaN      neutral -0.155078   0.73
#
#          CADDE   CADDS  ...     FATS  FATC         FUNE                  FUNS  \
# 0      neutral   2.258  ...  0.18997  0.77          NaN                   NaN
# 1  deleterious   9.461  ...  0.18963  0.77      neutral   8.51599164992024E-6
# 2  deleterious   9.779  ...  0.21184  0.75            ?     0.622785975437062
# 3  deleterious  13.690  ...  0.82375  0.82      neutral  7.52439751165574E-20
# 4      neutral   6.450  ...  0.95264  0.91  deleterious      1.19368630042138
#
#    FUNC   GWAVAE  GWAVAS GWAVAC           ID    GENE
# 0   NaN  neutral    0.30   0.68  rs552586867  COL4A1
# 1  0.80  neutral    0.32   0.71   rs59409892  COL4A1
# 2  0.49  neutral    0.32   0.71  rs535182970  COL4A1
# 3  0.80  neutral    0.44   0.53   rs56406633  COL4A1
# 4  0.74  neutral    0.44   0.53  rs568536001  COL4A1
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Save data to CSV file

# %%
pdtsnp2_vep_data.reset_index(drop=True).to_csv(
    os.path.join(
        constants.HOME_PATH,
        "Data",
        "Processed",
        "Variant_effects.csv",
    )
)
